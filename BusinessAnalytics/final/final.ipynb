# %%
import pandas as pd

# %%
data = pd.read_csv('applicants.csv')

# %%
data.head()
# Out:
#   Անուն Ազգանուն     Սեռ Տարիք Բջջային հեռախոսահամար  \
# 0   NaN      NaN     NaN   NaN                   NaN
# 1  Նանա  Թորոյան  Իգական    21              98907399
# 2   NaN      NaN     NaN   NaN                   NaN
# 3   NaN      NaN     NaN   NaN                   NaN
# 4   NaN      NaN     NaN   NaN                   NaN
#
#   Էլեկտրոնային հասցե (e-mail)   \
# 0                          NaN
# 1      nanpelelove35@gmail.com
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#   Միջինում քանի՞ ժամ կարող եք օրական տրամադրել կամավորական աշխատանքին: Նշեք նախընտրելի ժամանակահատվածները:  \
# 0                                                NaN
# 1           Հասանելի եմ երեկոյան և գիշերային ժամերին
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#       Խոսակցական անգլերենի ձեր իմացության մակարդակը՝  \
# ...

# %%
data.columns
# Out:
# Index(['Անուն', 'Ազգանուն', 'Սեռ', 'Տարիք', 'Բջջային հեռախոսահամար',
#        'Էլեկտրոնային հասցե (e-mail) ',
#        'Միջինում քանի՞ ժամ կարող եք օրական տրամադրել կամավորական աշխատանքին: Նշեք նախընտրելի ժամանակահատվածները:',
#        'Խոսակցական անգլերենի ձեր իմացության մակարդակը՝',
#        'Ուրիշ ի՞նչ լեզուների եք տիրապետում և ի՞նչ մակարդակի:',
#        'Կրթություն / Մասնագիտություն.', 'Ներկայիս զբաղվածություն.',
#        'Ի՞նչ աշխատանք կցանկանայիք կատարել նախագծի ընթացքում?',
#        'Ինչու՞ եք ցանկանում դառնալ կամավոր 2018թ. «Ավրորա» մրցանակի շնորհման արարողության եւ ուղեկցող միջոցառումների ընթացքում:',
#        'Եթե նախկինում ունեցել եք  կամավորական աշխատանքի փորձ, խնդրում ենք մանրամասնել։',
#        'Կատարե՞լ եք արդյոք կամավորական աշխատանք 2016թ. «Ավրորա» մրցանակի միջոցառումների շրջանակներում:',
#        'Կատարե՞լ եք արդյոք կամավորական աշխատանք 2017թ. «Ավրորա» մրցանակի միջոցառումների շրջանակներում:',
#        'IDeA հիմնադրամի ի՞նչ այլ ծրագրերով եք հետաքրքրված.',
# ...

# %%
data['Էլեկտրոնային հասցե (e-mail) ']
# Out:
# 0                                   NaN
# 1               nanpelelove35@gmail.com
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5         nora.harutyunyan.1995@mail.ru
# 6                                   NaN
# 7               lima.zaqaryan@gmail.com
# 8                     sghukeyan@mail.ru
# 9         yana.gevorgyan.245@gmail.com
# 10             shharutyunyan5@gmail.com
# 11               lady.tsarukyan@mail.ru
# 12                                  NaN
# 13                   anigrigg@gmail.com
# 14                                  NaN
# 15                                  NaN
# 16             anushananyan25@gmail.com
# 17             Rafyengibarian@gmail.com
# 18                        marrela@bk.ru
# 19                                  NaN
# 20                galstyankim@gmail.com
# 21          hovik.vanyan.2001@gmail.com
# 22        raya.hovhannisyan69@gmail.com
# ...
